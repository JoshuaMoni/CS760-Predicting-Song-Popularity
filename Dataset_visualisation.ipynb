# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import billboard
import requests, os, sys, json, orjson

import deepdish
import tables
import h5py
import sklearn,scipy
from tqdm import tqdm

import torch
print(f"Torch Version: {torch.__version__}")
print(f"Using GPU: {torch.cuda.is_available()}")
# Out:
# Torch Version: 2.0.0
# Using GPU: True

# %%
data_files = [x for x in os.listdir('data/') if x.endswith('.json')]

def extract_songs(row):
    """Helper function to be used with apply"""
    return pd.DataFrame(row).drop('pos', axis=1).drop_duplicates()

def rip_songs(json_files):
    """Generates the song dataset"""
    df_list = []

    for file in tqdm(json_files, total=len(json_files), desc='Reading JSON Data'): 
        with open(os.path.join('data/', file), 'rb') as f: 
            content = orjson.loads(f.read())
        
        playlists = pd.DataFrame(content['playlists'])['tracks']
        df_list.append(pd.concat(playlists.apply(extract_songs).tolist(), ignore_index=True).drop_duplicates().reset_index(drop=True))
    
    return pd.concat(df_list).drop_duplicates().reset_index(drop=True)

data = rip_songs(json_files=data_files)

if 'All_unique_songs.pkl' not in os.listdir():
    data.to_pickle('All_unique_songs.pkl')
    
data
# Out:
# Reading JSON Data: 100%|██████████| 1000/1000 [34:44<00:00,  2.08s/it]
#                artist_name                             track_uri  \
# 0            Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1           Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2                  Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3        Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                   Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                    ...                                   ...
# 2262287             Pax217  spotify:track:2aOoiTTV0OR8DYxCk8o0JR
# 2262288             Pax217  spotify:track:1Uo65qTxnCg1N1X00lgcjr
# 2262289             Pax217  spotify:track:5uEE5tii66I0cC7kZ7IMxE
# 2262290             Pax217  spotify:track:6A1RfnrMdxb24OYllzzTUX
# 2262291       Straw Theory  spotify:track:5DvykFHB6utG6Hozpt5eNK
#
#                                     artist_uri  \
# 0        spotify:artist:2wIVse2owClT7go1WT98tk
# 1        spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2        spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3        spotify:artist:31TPClRtHm23RisEBtV3X7
# 4        spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                                        ...
# 2262287  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 2262288  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 2262289  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 2262290  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 2262291  spotify:artist:2stBqJCSWouhEQwwW3x3RK
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 2262287          Forevermind - Pax217 Album Version
# 2262288               Shalom - Pax217 Album Version
# 2262289           Free To Be - Pax217 Album Version
# 2262290                Skwid - Pax217 Album Version
# 2262291                                Running Thin
#
#                                     album_uri  duration_ms  \
# 0        spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1        spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2        spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3        spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4        spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# ...                                       ...          ...
# 2262287  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       206400
# 2262288  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       268266
# 2262289  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       334280
# 2262290  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       240453
# 2262291  spotify:album:60Nz1KLyK6hhOhTZjlGZQI       341933
#
#                                            album_name
# 0                                        The Cookbook
# 1                                         In The Zone
# 2        Dangerously In Love (Alben für die Ewigkeit)
# 3                                           Justified
# 4                                            Hot Shot
# ...                                               ...
# 2262287                                 Two Seventeen
# 2262288                                 Two Seventeen
# 2262289                                 Two Seventeen
# 2262290                                 Two Seventeen
# 2262291                              The Straw Theory
#
# [2262292 rows x 7 columns]

# %%
artist_counts = data.artist_name.value_counts()
valid_artists = artist_counts[artist_counts > 10].index.values

data[(data.artist_name.isin(valid_artists)) & (data.duration_ms < 600000)].reset_index(drop=True)#.describe()
# Out:
#                artist_name                             track_uri  \
# 0            Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1           Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2                  Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3        Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                   Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                    ...                                   ...
# 1651012             Pax217  spotify:track:10UkkV6hmRLToXqnNbhdEF
# 1651013             Pax217  spotify:track:2aOoiTTV0OR8DYxCk8o0JR
# 1651014             Pax217  spotify:track:1Uo65qTxnCg1N1X00lgcjr
# 1651015             Pax217  spotify:track:5uEE5tii66I0cC7kZ7IMxE
# 1651016             Pax217  spotify:track:6A1RfnrMdxb24OYllzzTUX
#
#                                     artist_uri  \
# 0        spotify:artist:2wIVse2owClT7go1WT98tk
# 1        spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2        spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3        spotify:artist:31TPClRtHm23RisEBtV3X7
# 4        spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                                        ...
# 1651012  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 1651013  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 1651014  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 1651015  spotify:artist:52BrJWa29mZPy5hgDIs6d0
# 1651016  spotify:artist:52BrJWa29mZPy5hgDIs6d0
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 1651012            Gratitude - Pax217 Album Version
# 1651013          Forevermind - Pax217 Album Version
# 1651014               Shalom - Pax217 Album Version
# 1651015           Free To Be - Pax217 Album Version
# 1651016                Skwid - Pax217 Album Version
#
#                                     album_uri  duration_ms  \
# 0        spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1        spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2        spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3        spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4        spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# ...                                       ...          ...
# 1651012  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       158386
# 1651013  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       206400
# 1651014  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       268266
# 1651015  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       334280
# 1651016  spotify:album:5ULVqJFwZ8AQ1Dldq9ZDby       240453
#
#                                            album_name
# 0                                        The Cookbook
# 1                                         In The Zone
# 2        Dangerously In Love (Alben für die Ewigkeit)
# 3                                           Justified
# 4                                            Hot Shot
# ...                                               ...
# 1651012                                 Two Seventeen
# 1651013                                 Two Seventeen
# 1651014                                 Two Seventeen
# 1651015                                 Two Seventeen
# 1651016                                 Two Seventeen
#
# [1651017 rows x 7 columns]

# %% [markdown]
# # data.world/typhon/billboard-hot-100-songs-2000-2018-w-spotify-data-lyrics

# %%
data = pd.read_csv('billboard_2000_2018_spotify_lyrics.csv').drop(columns=['simple_title','main_artist', 'spotify_link','spotify_id','video_link','analysis_url', 'time_signature','speechiness','acousticness','instrumentalness','key','mode','date','year','duration_ms']).dropna(axis=0).drop_duplicates(subset=['artist','title'])
data = data[~(data.lyrics == 'Error: Could not find lyrics.')].reset_index(drop=True)
data
# Out:
#                                                   title              artist  \
# 0                                      ...Ready For It?        taylor swift
# 1                                        1-800-273-8255               logic
# 2                               A Holly Jolly Christmas           burl ives
# 3                       All I Want For Christmas Is You        mariah carey
# 4                                             Attention        charlie puth
# ...                                                 ...                 ...
# 6758                                          This Gift          98 degrees
# 6759                                     Deck The Halls            shedaisy
# 6760                                         I Love You     martina mcbride
# 6761                                       Left & Right            d'angelo
# 6762  The Christmas Song (Chestnuts Roasting On An O...  christina aguilera
#
#       peak_pos  last_pos  weeks  rank change  \
# 0            4        59     17    61     -2
# 1            3        34     35    34      0
# 2           38        38      5    46     -8
# 3            9         9     24    13     -4
# 4            5        44     36    39      5
# ...        ...       ...    ...   ...    ...
# 6758        49        49      3    79    -30
# 6759        61        69      3    61      8
# 6760        24        66     20    71     -5
# 6761        70        70      5    91    -21
# 6762        18        18      4    18      0
#
#                                                   genre broad_genre energy  \
# 0              [u'dance pop', u'pop', u'post-teen pop']         pop  0.776
# 1                                              [u'rap']         rap  0.572
# 2                                        [u'christmas']     unknown  0.363
# 3     [u'dance pop', u'hip pop', u'pop', u'pop rap',...         r&b  0.625
# 4     [u'dance pop', u'pop', u'post-teen pop', u'vir...         pop  0.626
# ...                                                 ...         ...    ...
# 6758                                     [u'dance pop']         pop  0.529
# 6759  [u'contemporary country', u'country', u'countr...     country  0.837
# 6760  [u'contemporary country', u'country', u'countr...     country  0.586
# 6761  [u'funk', u'hip hop', u'indie r&b', u'neo soul...         r&b  0.405
# 6762  [u'dance pop', u'europop', u'pop', u'post-teen...         r&b    0.3
#
#      liveness    tempo danceability loudness valence  \
# 0       0.155  160.053        0.616   -6.519   0.459
# 1       0.192  100.015        0.629   -7.733   0.386
# 2        0.15  140.296        0.665  -12.983   0.824
# 3      0.0708  150.277        0.335   -7.462   0.346
# 4      0.0848  100.041        0.774   -4.432   0.777
# ...       ...      ...          ...      ...     ...
# 6758   0.0824   86.984        0.623   -8.649   0.423
# 6759    0.144  118.827        0.575   -7.141   0.444
# 6760    0.132  106.754        0.687   -5.991   0.732
# 6761    0.383   92.115        0.838   -9.684   0.843
# 6762    0.105    71.31        0.392   -8.452   0.147
#
#                                                  lyrics
# 0     Knew he was a killer, first time that I saw hi...
# 1     I've been on the low\nI been taking my time\nI...
# 2     Ding Dong Ding\nDing dong ding\nHave a holly j...
# 3     I don't want a lot for Christmas\nThere is jus...
# 4     You've been running 'round, running 'round, ru...
# ...                                                 ...
# 6758  The snow is fallin' The city is white\nYou're ...
# 6759  Deck the halls\n(Deck the halls)\nWith boughs ...
# 6760  She dropped the phone and burst into tears\nTh...
# 6761  Yo, yo\nMy flows remarkable\n\nDoc walk like K...
# 6762  Chestnuts roasting on an open fire\nJack Frost...
#
# [6763 rows x 16 columns]

# %% [markdown]
# # Million Song Subset

# %%
shpfiles = [os.path.join(d, x)
            for d, dirs, files in os.walk('MillionSongSubset')
            for x in files if x.endswith(".h5")]

#pd.DataFrame(deepdish.io.load(shpfiles[0])).T

keys = ['analysis', 'metadata', 'musicbrainz']
f = h5py.File(shpfiles[0], 'r')
t = f[keys[0]]
tt = f[keys[1]]
list(t.values())
# Out:
# [<HDF5 dataset "bars_confidence": shape (83,), type "<f8">,
#  <HDF5 dataset "bars_start": shape (83,), type "<f8">,
#  <HDF5 dataset "beats_confidence": shape (344,), type "<f8">,
#  <HDF5 dataset "beats_start": shape (344,), type "<f8">,
#  <HDF5 dataset "sections_confidence": shape (10,), type "<f8">,
#  <HDF5 dataset "sections_start": shape (10,), type "<f8">,
#  <HDF5 dataset "segments_confidence": shape (971,), type "<f8">,
#  <HDF5 dataset "segments_loudness_max": shape (971,), type "<f8">,
#  <HDF5 dataset "segments_loudness_max_time": shape (971,), type "<f8">,
#  <HDF5 dataset "segments_loudness_start": shape (971,), type "<f8">,
#  <HDF5 dataset "segments_pitches": shape (971, 12), type "<f8">,
#  <HDF5 dataset "segments_start": shape (971,), type "<f8">,
#  <HDF5 dataset "segments_timbre": shape (971, 12), type "<f8">,
#  <HDF5 dataset "songs": shape (1,), type "|V220">,
#  <HDF5 dataset "tatums_confidence": shape (688,), type "<f8">,
#  <HDF5 dataset "tatums_start": shape (688,), type "<f8">]

# %%
pd.read_csv('top10s.csv', encoding='ISO-8859-1', index_col=0)
# Out:
#                                                  title            artist  \
# 1                                     Hey, Soul Sister             Train
# 2                                 Love The Way You Lie            Eminem
# 3                                              TiK ToK             Kesha
# 4                                          Bad Romance         Lady Gaga
# 5                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 599                Find U Again (feat. Camila Cabello)       Mark Ronson
# 600      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 601  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 602    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 603                                   Kills You Slowly  The Chainsmokers
#
#            top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 1         neo mellow  2010   97    89    67  -4     8   80  217     19     4
# 2    detroit hip hop  2010   87    93    75  -5    52   64  263     24    23
# 3          dance pop  2010  120    84    76  -3    29   71  200     10    14
# 4          dance pop  2010  119    92    70  -4     8   71  295      0     4
# 5                pop  2010  109    84    64  -5     9   43  221      2     4
# ..               ...   ...  ...   ...   ...  ..   ...  ...  ...    ...   ...
# 599        dance pop  2019  104    66    61  -7    20   16  176      1     3
# 600              pop  2019   95    79    75  -6     7   61  206     21    12
# 601        dance pop  2019  136    76    53  -5     9   65  260      7    34
# 602        dance pop  2019  114    79    60  -6    42   24  217      1     7
# 603       electropop  2019  150    44    70  -9    13   23  213      6     6
#
#      pop
# 1     83
# 2     82
# 3     80
# 4     79
# 5     78
# ..   ...
# 599   75
# 600   75
# 601   70
# 602   69
# 603   67
#
# [603 rows x 14 columns]

# %%
token = f"953a5886c15d403294f4d974c513e44e"
endpoint = 'https://api.spotify.com/v1/me/top/tracks'
bearer = f'95d5c1d2865d4413b9312244603a5547'
headers = {bearer : token}
response = requests.get(endpoint, headers=headers)#, params=params)

# %%
chart = billboard.ChartData('hot-100-songs', year=2012)
chart
# Out:
# billboard.ChartData('hot-100-songs', year=2012)

# %%
chart2 = billboard.ChartData('pop-songs', year=2012)

# %%
list(chart2)
# Out:
# [billboard.YearEndChartEntry(title='Lights', artist='Ellie Goulding'),
#  billboard.YearEndChartEntry(title='We Found Love', artist='Rihanna Featuring Calvin Harris'),
#  billboard.YearEndChartEntry(title='Glad You Came', artist='The Wanted'),
#  billboard.YearEndChartEntry(title='Call Me Maybe', artist='Carly Rae Jepsen'),
#  billboard.YearEndChartEntry(title='Payphone', artist='Maroon 5 Featuring Wiz Khalifa'),
#  billboard.YearEndChartEntry(title='Good Feeling', artist='Flo Rida'),
#  billboard.YearEndChartEntry(title='We Are Young', artist='fun. Featuring Janelle Monae'),
#  billboard.YearEndChartEntry(title='Somebody That I Used To Know', artist='Gotye Featuring Kimbra'),
#  billboard.YearEndChartEntry(title='Wide Awake', artist='Katy Perry'),
#  billboard.YearEndChartEntry(title='Set Fire To The Rain', artist='Adele'),
#  billboard.YearEndChartEntry(title="Stronger (What Doesn't Kill You)", artist='Kelly Clarkson'),
#  billboard.YearEndChartEntry(title='It Will Rain', artist='Bruno Mars'),
#  billboard.YearEndChartEntry(title='Starships', artist='Nicki Minaj'),
#  billboard.YearEndChartEntry(title='The One That Got Away', artist='Katy Perry'),
#  billboard.YearEndChartEntry(title='What Makes You Beautiful', artist='One Direction'),
#  billboard.YearEndChartEntry(title='Where Have You Been', artist='Rihanna'),
#  billboard.YearEndChartEntry(title='Wild Ones', artist='Flo Rida Featuring Sia'),
#  billboard.YearEndChartEntry(title='Give Your Heart A Break', artist='Demi Lovato'),
#  billboard.YearEndChartEntry(title='Blow Me (One Last Kiss)', artist='P!nk'),
#  billboard.YearEndChartEntry(title='One More Night', artist='Maroon 5'),
#  billboard.YearEndChartEntry(title='Domino', artist='Jessie J'),
#  billboard.YearEndChartEntry(title='Turn Me On', artist='David Guetta Featuring Nicki Minaj'),
#  billboard.YearEndChartEntry(title='Titanium', artist='David Guetta Featuring Sia'),
#  billboard.YearEndChartEntry(title='Part Of Me', artist='Katy Perry'),
#  billboard.YearEndChartEntry(title='Sexy And I Know It', artist='LMFAO'),
#  billboard.YearEndChartEntry(title='Everybody Talks', artist='Neon Trees'),
#  billboard.YearEndChartEntry(title='Good Time', artist='Owl City & Carly Rae Jepsen'),
#  billboard.YearEndChartEntry(title='As Long As You Love Me', artist='Justin Bieber Featuring Big Sean'),
#  billboard.YearEndChartEntry(title='Whistle', artist='Flo Rida'),
#  billboard.YearEndChartEntry(title='Some Nights', artist='fun.'),
#  billboard.YearEndChartEntry(title='Ass Back Home', artist='Gym Class Heroes Featuring Neon Hitch'),
#  billboard.YearEndChartEntry(title='Scream', artist='Usher'),
#  billboard.YearEndChartEntry(title='Without You', artist='David Guetta Featuring Usher'),
#  billboard.YearEndChartEntry(title='We Are Never Ever Getting Back Together', artist='Taylor Swift'),
#  billboard.YearEndChartEntry(title='Too Close', artist='Alex Clare'),
#  billboard.YearEndChartEntry(title='Boyfriend', artist='Justin Bieber'),
#  billboard.YearEndChartEntry(title='Love You Like A Love Song', artist='Selena Gomez & The Scene'),
#  billboard.YearEndChartEntry(title="Let's Go", artist='Calvin Harris Featuring Ne-Yo'),
#  billboard.YearEndChartEntry(title='International Love', artist='Pitbull Featuring Chris Brown'),
#  billboard.YearEndChartEntry(title='Feel So Close', artist='Calvin Harris'),
#  billboard.YearEndChartEntry(title='Brokenhearted', artist='Karmin'),
#  billboard.YearEndChartEntry(title='Stereo Hearts', artist='Gym Class Heroes Featuring Adam Levine'),
#  billboard.YearEndChartEntry(title='Take Care', artist='Drake Featuring Rihanna'),
#  billboard.YearEndChartEntry(title='Not Over You', artist='Gavin DeGraw'),
#  billboard.YearEndChartEntry(title='Want U Back', artist='Cher Lloyd'),
#  billboard.YearEndChartEntry(title='Rumour Has It', artist='Adele'),
#  billboard.YearEndChartEntry(title='Drive By', artist='Train'),
#  billboard.YearEndChartEntry(title="Don't Wake Me Up", artist='Chris Brown'),
#  billboard.YearEndChartEntry(title='Young, Wild & Free', artist='Snoop Dogg & Wiz Khalifa Featuring Bruno Mars'),
#  billboard.YearEndChartEntry(title='Moves Like Jagger', artist='Maroon 5 Featuring Christina Aguilera')]
